# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset/ndvi-lluvia-tmin-tmax.csv")
df.head()
# Out:
#    anio  mes ADM2_PCODE departamento              municipio  n_pixels  \
# 0  2002    7     GT0100    Guatemala      Lago De Amatitlan       1.0
# 1  2002    7     GT0101    Guatemala              Guatemala       6.0
# 2  2002    7     GT0102    Guatemala  Santa Catarina Pinula       2.0
# 3  2002    7     GT0103    Guatemala        San José Pinula       5.0
# 4  2002    7     GT0104    Guatemala     San José del Golfo       2.0
#
#         vim         viq        lon        lat  precipitacion       tmin  \
# 0  0.686067  100.902100 -90.548878  14.435029      169.31514  16.139826
# 1  0.586433  101.562333 -90.479418  14.635431      191.59773  15.752864
# 2  0.707967  101.330167 -90.465079  14.564392      186.14903  14.537229
# 3  0.796333  100.334500 -90.346363  14.554316      199.11770  11.996284
# 4  0.774200   98.992867 -90.372463  14.793193      135.58841  19.454800
#
#         tmax        date    tdelta
# 0  25.118555  2002-07-11  8.978729
# 1  25.048338  2002-07-11  9.295474
# 2  23.773886  2002-07-11  9.236657
# 3  20.399480  2002-07-11  8.403196
# 4  28.777624  2002-07-11  9.322824

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81264 entries, 0 to 81263
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anio           81264 non-null  int64
#  1   mes            81264 non-null  int64
#  2   ADM2_PCODE     81264 non-null  object
#  3   departamento   81264 non-null  object
#  4   municipio      81264 non-null  object
#  5   n_pixels       81264 non-null  float64
#  6   vim            81264 non-null  float64
#  7   viq            81264 non-null  float64
#  8   lon            81264 non-null  float64
#  9   lat            81264 non-null  float64
#  10  precipitacion  81264 non-null  float64
#  11  tmin           81264 non-null  float64
#  12  tmax           81264 non-null  float64
#  13  date           81264 non-null  object
#  14  tdelta         81264 non-null  float64
# dtypes: float64(9), int64(2), object(4)
# memory usage: 9.3+ MB

# %%
df.isna().sum(axis=0)
# Out:
# anio             0
# mes              0
# ADM2_PCODE       0
# departamento     0
# municipio        0
# n_pixels         0
# vim              0
# viq              0
# lon              0
# lat              0
# precipitacion    0
# tmin             0
# tmax             0
# date             0
# tdelta           0
# dtype: int64

# %%
df.describe()
# Out:
#                anio           mes      n_pixels           vim           viq  \
# count  81264.000000  81264.000000  81264.000000  81264.000000  81264.000000
# mean    2012.744955      6.569723     11.378470      0.714961    100.391691
# std        6.209488      3.451455     24.642132      0.111696      3.372495
# min     2002.000000      1.000000      1.000000      0.249600     75.766933
# 25%     2007.000000      4.000000      2.000000      0.649400     98.818092
# 50%     2013.000000      7.000000      5.000000      0.753200    100.268633
# 75%     2018.000000     10.000000     10.000000      0.800633    101.845608
# max     2023.000000     12.000000    275.000000      0.891533    127.307033
#
#                 lon           lat  precipitacion          tmin          tmax  \
# count  81264.000000  81264.000000   81264.000000  81264.000000  81264.000000
# mean     -90.828353     14.929289     156.292752     14.651970     27.186788
# std        0.798608      0.597030     159.071855      5.880862      5.183560
# min      -92.119786     13.910458       0.000000     -5.192460      9.929691
# 25%      -91.533353     14.549615      22.345301     10.055494     23.044897
# 50%      -90.898669     14.823235     112.010750     15.476129     27.651499
# 75%      -90.203816     15.197355     243.600020     19.569326     31.635446
# max      -88.490611     17.489473    1306.445800     34.548480     40.322803
#
#              tdelta
# count  81264.000000
# mean      12.534818
# std        2.695169
# min        0.573089
# 25%       10.634424
# 50%       12.263837
# 75%       14.183608
# max       25.853220

# %%
df.shape
# Out:
# (81264, 15)

# %%
plt.figure(figsize=(14, 8))
sns.heatmap(df.corr(), cmap="coolwarm", annot=True, center=0)
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/1095577018.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="coolwarm", annot=True, center=0)
# <Axes: >

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="vim", y="departamento")
# Out:
# <Axes: xlabel='vim', ylabel='departamento'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="vim", y="mes", orient="h")
# Out:
# <Axes: xlabel='vim', ylabel='mes'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="vim", y="anio", orient="h")
# Out:
# <Axes: xlabel='vim', ylabel='anio'>

# %%
plt.figure(figsize=(14, 8))
sns.histplot(df, x="vim")
# Out:
# <Axes: xlabel='vim', ylabel='Count'>

# %%
plt.figure(figsize=(14, 8))
sns.histplot(df, x="viq")
# Out:
# <Axes: xlabel='viq', ylabel='Count'>

# %%
sns.countplot(df, x="anio")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(df, x="precipitacion", y="vim", alpha=0.05)
# Out:
# <Axes: xlabel='precipitacion', ylabel='vim'>

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(df, x="tdelta", y="vim", alpha=0.05)
# Out:
# <Axes: xlabel='tdelta', ylabel='vim'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="viq", y="mes", orient="h")
# Out:
# <Axes: xlabel='viq', ylabel='mes'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="viq", y="anio", orient="h")
# Out:
# <Axes: xlabel='viq', ylabel='anio'>

# %%
promedio_municipio = df.groupby(by="ADM2_PCODE").mean().reset_index()
promedio_municipio
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/3357884568.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   promedio_municipio = df.groupby(by="ADM2_PCODE").mean().reset_index()
#     ADM2_PCODE         anio       mes  n_pixels       vim         viq  \
# 0       GT0100  2012.744186  6.569767       1.0  0.586015   99.668550
# 1       GT0101  2012.744186  6.569767       6.0  0.495854   99.793935
# 2       GT0102  2012.744186  6.569767       2.0  0.649732  100.375662
# 3       GT0103  2012.744186  6.569767       5.0  0.750555  100.423461
# 4       GT0104  2012.744186  6.569767       2.0  0.654073  100.158222
# ..         ...          ...       ...       ...       ...         ...
# 310     GT2213  2012.744186  6.569767       4.0  0.667733  100.812055
# 311     GT2214  2012.744186  6.569767      14.0  0.718227  100.452142
# 312     GT2215  2012.744186  6.569767       5.0  0.701824  100.689083
# 313     GT2216  2012.744186  6.569767       4.0  0.773713  100.813873
# 314     GT2217  2012.744186  6.569767       5.0  0.664279  100.679030
#
#            lon        lat  precipitacion       tmin       tmax     tdelta
# 0   -90.548878  14.435029     157.162746  15.426287  25.375911   9.949624
# 1   -90.479418  14.635431     121.781601  15.012501  25.169098  10.156597
# 2   -90.465079  14.564392     124.007071  13.765099  23.951313  10.186214
# 3   -90.346363  14.554316     136.112721  11.154456  20.703482   9.549027
# 4   -90.372463  14.793193     106.216238  18.468180  28.671301  10.203121
# ..         ...        ...            ...        ...        ...        ...
# 310 -90.016291  14.009939     157.589045  17.817059  30.185094  12.368035
# 311 -90.125606  13.910458     154.263543  21.850330  33.321702  11.471372
# 312 -90.263685  13.967475     147.997031  22.523901  34.309518  11.785617
# 313 -90.145611  14.272053     124.130605  15.116868  27.498939  12.382070
# 314 -90.059508  14.285650     110.512231  16.667029  29.099960  12.432931
#
# [315 rows x 12 columns]

# %%
promedio_departamento = df.groupby(by="departamento").mean().reset_index()
promedio_departamento.head()
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/3646937710.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   promedio_departamento = df.groupby(by="departamento").mean().reset_index()
#     departamento         anio       mes   n_pixels       vim         viq  \
# 0   Alta Verapaz  2012.744186  6.569767  21.000000  0.806044   99.904567
# 1   Baja Verapaz  2012.744186  6.569767  12.625000  0.710832  100.232951
# 2  Chimaltenango  2012.749394  6.569074   3.938682  0.707959  100.077020
# 3     Chiquimula  2012.744186  6.569767   7.090909  0.673504  100.863985
# 4    El Progreso  2012.744186  6.569767   7.875000  0.672501  100.254662
#
#          lon        lat  precipitacion       tmin       tmax     tdelta
# 0 -90.089375  15.520189     204.483477  16.722834  28.796734  12.073900
# 1 -90.389604  15.093024     112.909276  14.176044  28.116132  13.940088
# 2 -90.921939  14.672445     120.848403  10.766339  23.290105  12.523766
# 3 -89.442140  14.686655     131.438990  18.079662  29.399669  11.320007
# 4 -90.081571  14.883000     102.751767  17.841414  29.417683  11.576269

# %%
import geopandas

# %%
gt = geopandas.read_file("dataset/gtm_adm_ocha_conred_2019_SHP/gtm_admbnda_adm1_ocha_conred_20190207.shp")
gt = gt[["ADM1_ES", "geometry"]]
gt.rename(columns={"ADM1_ES": "departamento"}, inplace=True)
promedio_departamento = gt.merge(promedio_departamento, "outer", on="departamento")
promedio_departamento.head()
# Out:
#     departamento                                           geometry  \
# 0   Alta Verapaz  POLYGON ((-90.40980 16.06946, -90.39227 16.067...
# 1   Baja Verapaz  POLYGON ((-90.63282 15.29192, -90.63240 15.278...
# 2  Chimaltenango  POLYGON ((-90.99903 14.93806, -90.99836 14.937...
# 3     Chiquimula  POLYGON ((-89.19070 14.90096, -89.19645 14.899...
# 4    El Progreso  POLYGON ((-89.93963 15.14023, -89.93376 15.139...
#
#           anio       mes   n_pixels       vim         viq        lon  \
# 0  2012.744186  6.569767  21.000000  0.806044   99.904567 -90.089375
# 1  2012.744186  6.569767  12.625000  0.710832  100.232951 -90.389604
# 2  2012.749394  6.569074   3.938682  0.707959  100.077020 -90.921939
# 3  2012.744186  6.569767   7.090909  0.673504  100.863985 -89.442140
# 4  2012.744186  6.569767   7.875000  0.672501  100.254662 -90.081571
#
#          lat  precipitacion       tmin       tmax     tdelta
# 0  15.520189     204.483477  16.722834  28.796734  12.073900
# 1  15.093024     112.909276  14.176044  28.116132  13.940088
# 2  14.672445     120.848403  10.766339  23.290105  12.523766
# 3  14.686655     131.438990  18.079662  29.399669  11.320007
# 4  14.883000     102.751767  17.841414  29.417683  11.576269

# %%
VEG_CMAP = sns.color_palette("blend:chocolate,olive,forestgreen", as_cmap=True)
VEG_CMAP

# %%
VEG_CMAP_0 = sns.color_palette("blend:chocolate,lightgray,forestgreen", as_cmap=True)
VEG_CMAP_0

# %%
LLUVIA_CMAP = sns.color_palette("blend:lightblue,royalblue,indigo", as_cmap=True)
LLUVIA_CMAP

# %%
TEMP_CMAP = sns.color_palette("blend:lightsalmon,indianred,maroon", as_cmap=True)
TEMP_CMAP

# %%
promedio_departamento.plot(column="vim", cmap=VEG_CMAP, legend=True)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_departamento.plot(column="precipitacion", cmap=LLUVIA_CMAP, legend=True)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_departamento.plot(column="tmin", cmap=TEMP_CMAP, legend=True)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_departamento.plot(column="tmax", cmap=TEMP_CMAP, legend=True)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_departamento.plot(column="viq", cmap=VEG_CMAP_0, legend=True, vmin=99, vmax=101)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_departamento.plot(column="tdelta", cmap="viridis_r", legend=True)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
gt = geopandas.read_file("dataset/gtm_adm_ocha_conred_2019_SHP/gtm_admbnda_adm2_ocha_conred_20190207.shp")
gt = gt[["ADM2_PCODE", "geometry"]]
promedio_municipio = gt.merge(promedio_municipio, "outer", on="ADM2_PCODE")
promedio_municipio.head()
# Out:
#   ADM2_PCODE                                           geometry         anio  \
# 0     GT0411  POLYGON ((-90.96027 14.59634, -90.95620 14.594...  2012.744186
# 1     GT2204  POLYGON ((-89.54702 14.51849, -89.54562 14.518...  2012.744186
# 2     GT1327  POLYGON ((-91.17128 15.38646, -91.16989 15.384...  2012.744186
# 3     GT0913  POLYGON ((-91.46098 14.82363, -91.46459 14.820...  2012.744186
# 4     GT0314  POLYGON ((-90.81634 14.49698, -90.81160 14.495...  2012.744186
#
#         mes  n_pixels       vim         viq        lon        lat  \
# 0  6.569767       6.0  0.794955  100.195809 -90.956307  14.547826
# 1  6.569767      11.0  0.635909  100.602196 -89.599949  14.458206
# 2  6.569767      11.0  0.661134  100.792937 -91.213843  15.333277
# 3  6.569767       1.0  0.540993  100.049373 -91.484486  14.811737
# 4  6.569767       4.0  0.752809  100.090459 -90.819675  14.459525
#
#    precipitacion       tmin       tmax     tdelta
# 0     159.180754  16.152460  27.228780  11.076320
# 1     134.745302  18.912765  30.405738  11.492973
# 2     117.667557  14.624251  29.056242  14.431991
# 3      96.481463   7.002846  21.928545  14.925700
# 4     238.633461  14.098645  25.388927  11.290282

# %%
promedio_municipio.plot(column="vim", legend=True, cmap=VEG_CMAP)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_municipio.plot(column="precipitacion", legend=True, cmap=LLUVIA_CMAP)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_municipio.plot(column="tmin", legend=True, cmap=TEMP_CMAP)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_municipio.plot(column="tmax", legend=True, cmap=TEMP_CMAP)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_municipio.plot(column="viq", legend=True, cmap=VEG_CMAP_0, vmin=98.5, vmax=101.5)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_municipio.plot(column="tdelta", legend=True, cmap="viridis_r")
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
primer_anio = df[df.anio == 2003]
ultimo_anio = df[df.anio == 2023]

primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/3166147117.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/3166147117.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()

# %%
primer_anio = df[df.anio == 2003]
ultimo_anio = df[df.anio == 2023]

primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()

primer_anio = gt.merge(primer_anio, "outer", on="ADM2_PCODE")
ultimo_anio = gt.merge(ultimo_anio, "outer", on="ADM2_PCODE")

primer_anio["vim2003"] = primer_anio["vim"]
ultimo_anio["vim2023"] = ultimo_anio["vim"]

primer_ultimo = primer_anio.merge(ultimo_anio[["ADM2_PCODE", "vim2023"]], "inner", on="ADM2_PCODE")
primer_ultimo["diferencia"] = primer_ultimo.vim2023 - primer_ultimo.vim2003
primer_ultimo.head()
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/1755467739.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_1739/1755467739.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()
#   ADM2_PCODE                                           geometry    anio  mes  \
# 0     GT0411  POLYGON ((-90.96027 14.59634, -90.95620 14.594...  2003.0  6.5
# 1     GT2204  POLYGON ((-89.54702 14.51849, -89.54562 14.518...  2003.0  6.5
# 2     GT1327  POLYGON ((-91.17128 15.38646, -91.16989 15.384...  2003.0  6.5
# 3     GT0913  POLYGON ((-91.46098 14.82363, -91.46459 14.820...  2003.0  6.5
# 4     GT0314  POLYGON ((-90.81634 14.49698, -90.81160 14.495...  2003.0  6.5
#
#    n_pixels       vim         viq        lon        lat  precipitacion  \
# 0       6.0  0.795783  100.369192 -90.956307  14.547826     149.629705
# 1      11.0  0.639228  101.237178 -89.599949  14.458206     141.835426
# 2      11.0  0.636092   97.280111 -91.213843  15.333277     108.965265
# 3       1.0  0.522328   96.386239 -91.484486  14.811737      86.014365
# 4       4.0  0.752300  100.077611 -90.819675  14.459525     232.122204
#
#         tmin       tmax     tdelta   vim2003   vim2023  diferencia
# 0  11.388994  26.759670  15.370676  0.795783  0.801547    0.005764
# 1  18.119215  29.717991  11.598776  0.639228  0.650444    0.011217
# 2  13.342367  29.304803  15.962436  0.636092  0.683911    0.047819
# 3   7.049778  21.837597  14.787818  0.522328  0.561522    0.039194
# 4  13.086900  25.626809  12.539908  0.752300  0.758542    0.006242

# %%
primer_ultimo.plot(column="diferencia", legend=True, cmap=VEG_CMAP_0, vmin=-0.08, vmax=0.08)
plt.axis("off")
plt.title("Diferencia VIM 2023-2003")
# Out:
# Text(0.5, 1.0, 'Diferencia VIM 2023-2003')

# %%
fig, axes = plt.subplots(figsize=(14, 8), ncols=2, sharex="all", sharey="all")
ax1, ax2 = axes
primer_anio.plot(ax=ax1, column="viq", vmin=91, vmax=108, cmap=VEG_CMAP_0, legend=True)
ax1.axis("off")
im = ultimo_anio.plot(ax=ax2, column="viq", vmin=91, vmax=108, legend=True, cmap=VEG_CMAP_0)
ax2.axis("off")
plt.tight_layout()
