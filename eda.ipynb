# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ndvi-completo.csv")
df.head()
# Out:
#          date  adm2_id ADM2_PCODE  n_pixels     vim  vim_avg       viq  mes  \
# 0  2002-07-01    65298     GT1802       5.0  0.7442   0.7380  100.7902    7
# 1  2002-07-11    65298     GT1802       5.0  0.7446   0.7394  100.6574    7
# 2  2002-07-21    65298     GT1802       5.0  0.7452   0.7423  100.3636    7
# 3  2002-08-01    65298     GT1802       5.0  0.7461   0.7456  100.0641    8
# 4  2002-08-11    65298     GT1802       5.0  0.7476   0.7490   99.8260    8
#
#    anio  dia departamento   municipio        lat        lon
# 0  2002    1       Izabal  Lívingston -89.151105  15.777356
# 1  2002   11       Izabal  Lívingston -89.151105  15.777356
# 2  2002   21       Izabal  Lívingston -89.151105  15.777356
# 3  2002    1       Izabal  Lívingston -89.151105  15.777356
# 4  2002   11       Izabal  Lívingston -89.151105  15.777356

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247260 entries, 0 to 247259
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          247260 non-null  object
#  1   adm2_id       247260 non-null  int64
#  2   ADM2_PCODE    247260 non-null  object
#  3   n_pixels      247260 non-null  float64
#  4   vim           247260 non-null  float64
#  5   vim_avg       247260 non-null  float64
#  6   viq           247260 non-null  float64
#  7   mes           247260 non-null  int64
#  8   anio          247260 non-null  int64
#  9   dia           247260 non-null  int64
#  10  departamento  247260 non-null  object
#  11  municipio     247260 non-null  object
#  12  lat           247260 non-null  float64
#  13  lon           247260 non-null  float64
# dtypes: float64(6), int64(4), object(4)
# memory usage: 26.4+ MB

# %%
df.isna().sum(axis=0)
# Out:
# date            0
# adm2_id         0
# ADM2_PCODE      0
# n_pixels        0
# vim             0
# vim_avg         0
# viq             0
# mes             0
# anio            0
# dia             0
# departamento    0
# municipio       0
# lat             0
# lon             0
# dtype: int64

# %%
plt.figure(figsize=(14, 8))
sns.heatmap(df.corr(), cmap="coolwarm", annot=True, center=0)
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/1095577018.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="coolwarm", annot=True, center=0)
# <Axes: >

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="vim", y="departamento")
# Out:
# <Axes: xlabel='vim', ylabel='departamento'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="vim", y="mes", orient="h")
# Out:
# <Axes: xlabel='vim', ylabel='mes'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="vim", y="anio", orient="h")
# Out:
# <Axes: xlabel='vim', ylabel='anio'>

# %%
plt.figure(figsize=(14, 8))
sns.histplot(df, x="vim")
# Out:
# <Axes: xlabel='vim', ylabel='Count'>

# %%
sns.countplot(df, x="anio")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(df, x="lat", y="vim", alpha=0.05)
# Out:
# <Axes: xlabel='lat', ylabel='vim'>

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(df, x="lon", y="vim", alpha=0.05)
# Out:
# <Axes: xlabel='lon', ylabel='vim'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="viq", y="mes", orient="h")
# Out:
# <Axes: xlabel='viq', ylabel='mes'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(df, x="viq", y="anio", orient="h")
# Out:
# <Axes: xlabel='viq', ylabel='anio'>

# %%
promedio_municipio = df.groupby(by="ADM2_PCODE").mean().reset_index()
promedio_municipio
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/3357884568.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   promedio_municipio = df.groupby(by="ADM2_PCODE").mean().reset_index()
#     ADM2_PCODE  adm2_id  n_pixels       vim   vim_avg         viq       mes  \
# 0       GT0100  65296.0       1.0  0.585042  0.587484   99.628383  6.530769
# 1       GT0101  64843.0       6.0  0.495123  0.496676   99.773380  6.530769
# 2       GT0102  64844.0       2.0  0.649319  0.646884  100.383455  6.530769
# 3       GT0103  64845.0       5.0  0.750327  0.746919  100.447673  6.530769
# 4       GT0104  64846.0       2.0  0.653033  0.651860  100.150563  6.530769
# ..         ...      ...       ...       ...       ...         ...       ...
# 310     GT2213  65169.0       4.0  0.666767  0.661560  100.854794  6.530769
# 311     GT2214  65170.0      14.0  0.717474  0.713996  100.483520  6.530769
# 312     GT2215  65171.0       5.0  0.701069  0.695917  100.733891  6.530769
# 313     GT2216  65172.0       4.0  0.773514  0.766837  100.862564  6.530769
# 314     GT2217  65173.0       5.0  0.663397  0.659183  100.695866  6.530769
#
#             anio   dia        lat        lon
# 0    2012.830769  11.0 -90.548878  14.435029
# 1    2012.830769  11.0 -90.479418  14.635431
# 2    2012.830769  11.0 -90.465079  14.564392
# 3    2012.830769  11.0 -90.346363  14.554316
# 4    2012.830769  11.0 -90.372463  14.793193
# ..           ...   ...        ...        ...
# 310  2012.830769  11.0 -90.016291  14.009939
# 311  2012.830769  11.0 -90.125606  13.910458
# 312  2012.830769  11.0 -90.263685  13.967475
# 313  2012.830769  11.0 -90.145611  14.272053
# 314  2012.830769  11.0 -90.059508  14.285650
#
# [315 rows x 11 columns]

# %%
promedio_departamento = df.groupby(by="departamento").mean().reset_index()
promedio_departamento.head()
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/3646937710.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   promedio_departamento = df.groupby(by="departamento").mean().reset_index()
#     departamento       adm2_id   n_pixels       vim   vim_avg         viq  \
# 0   Alta Verapaz  70973.176471  21.000000  0.806033  0.806835   99.907126
# 1   Baja Verapaz  65091.500000  12.625000  0.710428  0.708806  100.252676
# 2  Chimaltenango  64891.500000   3.937500  0.707436  0.707028  100.083007
# 3     Chiquimula  65144.000000   7.090909  0.673085  0.667118  100.899735
# 4    El Progreso  64863.500000   7.875000  0.671811  0.670006  100.268238
#
#         mes         anio   dia        lat        lon
# 0  6.530769  2012.830769  11.0 -90.089375  15.520189
# 1  6.530769  2012.830769  11.0 -90.389604  15.093024
# 2  6.530769  2012.830769  11.0 -90.921887  14.672423
# 3  6.530769  2012.830769  11.0 -89.442140  14.686655
# 4  6.530769  2012.830769  11.0 -90.081571  14.883000

# %%
import geopandas

# %%
gt = geopandas.read_file("gtm_adm_ocha_conred_2019_SHP/gtm_admbnda_adm1_ocha_conred_20190207.shp")
gt = gt[["ADM1_ES", "geometry"]]
gt.rename(columns={"ADM1_ES": "departamento"}, inplace=True)
promedio_departamento = gt.merge(promedio_departamento, "outer", on="departamento")
promedio_departamento.head()
# Out:
#     departamento                                           geometry  \
# 0   Alta Verapaz  POLYGON ((-90.40980 16.06946, -90.39227 16.067...
# 1   Baja Verapaz  POLYGON ((-90.63282 15.29192, -90.63240 15.278...
# 2  Chimaltenango  POLYGON ((-90.99903 14.93806, -90.99836 14.937...
# 3     Chiquimula  POLYGON ((-89.19070 14.90096, -89.19645 14.899...
# 4    El Progreso  POLYGON ((-89.93963 15.14023, -89.93376 15.139...
#
#         adm2_id   n_pixels       vim   vim_avg         viq       mes  \
# 0  70973.176471  21.000000  0.806033  0.806835   99.907126  6.530769
# 1  65091.500000  12.625000  0.710428  0.708806  100.252676  6.530769
# 2  64891.500000   3.937500  0.707436  0.707028  100.083007  6.530769
# 3  65144.000000   7.090909  0.673085  0.667118  100.899735  6.530769
# 4  64863.500000   7.875000  0.671811  0.670006  100.268238  6.530769
#
#           anio   dia        lat        lon
# 0  2012.830769  11.0 -90.089375  15.520189
# 1  2012.830769  11.0 -90.389604  15.093024
# 2  2012.830769  11.0 -90.921887  14.672423
# 3  2012.830769  11.0 -89.442140  14.686655
# 4  2012.830769  11.0 -90.081571  14.883000

# %%
VEG_CMAP = sns.color_palette("blend:chocolate,green", as_cmap=True)
VEG_CMAP

# %%
VEG_CMAP_0 = sns.color_palette("blend:chocolate,lightgray,green", as_cmap=True)
VEG_CMAP_0

# %%
promedio_departamento.plot(column="vim", cmap=VEG_CMAP, legend=True)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_departamento.plot(column="viq", cmap=VEG_CMAP_0, legend=True, vmin=99, vmax=101)
plt.axis("off")
# Out:
# (-92.44117971794999,
#  -88.02056028504994,
#  13.535442914050071,
#  18.023453868950064)

# %%
gt = geopandas.read_file("gtm_adm_ocha_conred_2019_SHP/gtm_admbnda_adm2_ocha_conred_20190207.shp")
gt = gt[["ADM2_PCODE", "geometry"]]
promedio_municipio = gt.merge(promedio_municipio, "outer", on="ADM2_PCODE")
promedio_municipio.head()
# Out:
#   ADM2_PCODE                                           geometry  adm2_id  \
# 0     GT0411  POLYGON ((-90.96027 14.59634, -90.95620 14.594...  64894.0
# 1     GT2204  POLYGON ((-89.54702 14.51849, -89.54562 14.518...  65160.0
# 2     GT1327  POLYGON ((-91.17128 15.38646, -91.16989 15.384...  65062.0
# 3     GT0913  POLYGON ((-91.46098 14.82363, -91.46459 14.820...  64966.0
# 4     GT0314  POLYGON ((-90.81634 14.49698, -90.81160 14.495...  64881.0
#
#    n_pixels       vim   vim_avg         viq       mes         anio   dia  \
# 0       6.0  0.794661  0.793037  100.200135  6.530769  2012.830769  11.0
# 1      11.0  0.634555  0.631477  100.595869  6.530769  2012.830769  11.0
# 2      11.0  0.660684  0.655118  100.823474  6.530769  2012.830769  11.0
# 3       1.0  0.539833  0.539989  100.029881  6.530769  2012.830769  11.0
# 4       4.0  0.752515  0.751757  100.099202  6.530769  2012.830769  11.0
#
#          lat        lon
# 0 -90.956307  14.547826
# 1 -89.599949  14.458206
# 2 -91.213843  15.333276
# 3 -91.484486  14.811737
# 4 -90.819675  14.459525

# %%
promedio_municipio.plot(column="vim", legend=True, cmap=VEG_CMAP)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
promedio_municipio.plot(column="viq", legend=True, cmap=VEG_CMAP_0, vmin=98.5, vmax=101.5)
plt.axis("off")
# Out:
# (-92.41021900109996,
#  -88.02203460489994,
#  13.535442914050071,
#  18.023453868950064)

# %%
primer_anio = df[df.anio == 2003]
ultimo_anio = df[df.anio == 2023]

primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/3166147117.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/3166147117.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()

# %%
primer_anio = df[df.anio == 2003]
ultimo_anio = df[df.anio == 2023]

primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()

primer_anio = gt.merge(primer_anio, "outer", on="ADM2_PCODE")
ultimo_anio = gt.merge(ultimo_anio, "outer", on="ADM2_PCODE")

primer_anio["vim2003"] = primer_anio["vim"]
ultimo_anio["vim2023"] = ultimo_anio["vim"]

primer_ultimo = primer_anio.merge(ultimo_anio[["ADM2_PCODE", "vim2023"]], "inner", on="ADM2_PCODE")
primer_ultimo["diferencia"] = primer_ultimo.vim2023 - primer_ultimo.vim2003
primer_ultimo.head()
# Out:
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/1755467739.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   primer_anio = primer_anio.groupby("ADM2_PCODE").mean().reset_index()
# /var/folders/sg/bv36hz0d5z36h52fqpd37kn80000gn/T/ipykernel_10817/1755467739.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ultimo_anio = ultimo_anio.groupby("ADM2_PCODE").mean().reset_index()
#   ADM2_PCODE                                           geometry  adm2_id  \
# 0     GT0411  POLYGON ((-90.96027 14.59634, -90.95620 14.594...  64894.0
# 1     GT2204  POLYGON ((-89.54702 14.51849, -89.54562 14.518...  65160.0
# 2     GT1327  POLYGON ((-91.17128 15.38646, -91.16989 15.384...  65062.0
# 3     GT0913  POLYGON ((-91.46098 14.82363, -91.46459 14.820...  64966.0
# 4     GT0314  POLYGON ((-90.81634 14.49698, -90.81160 14.495...  64881.0
#
#    n_pixels       vim   vim_avg         viq  mes    anio   dia        lat  \
# 0       6.0  0.795783  0.792789  100.369192  6.5  2003.0  11.0 -90.956307
# 1      11.0  0.639228  0.630042  101.237178  6.5  2003.0  11.0 -89.599949
# 2      11.0  0.636092  0.654197   97.280111  6.5  2003.0  11.0 -91.213843
# 3       1.0  0.522328  0.538742   96.386239  6.5  2003.0  11.0 -91.484486
# 4       4.0  0.752300  0.751461  100.077611  6.5  2003.0  11.0 -90.819675
#
#          lon   vim2003   vim2023  diferencia
# 0  14.547826  0.795783  0.801547    0.005764
# 1  14.458206  0.639228  0.650444    0.011217
# 2  15.333277  0.636092  0.683911    0.047819
# 3  14.811737  0.522328  0.561522    0.039194
# 4  14.459525  0.752300  0.758542    0.006242

# %%
primer_ultimo.plot(column="diferencia", legend=True, cmap=VEG_CMAP_0, vmin=-0.08, vmax=0.08)
plt.axis("off")
plt.title("Diferencia VIM 2023-2003")
# Out:
# Text(0.5, 1.0, 'Diferencia VIM 2023-2003')

# %%
fig, axes = plt.subplots(figsize=(14, 8), ncols=2, sharex="all", sharey="all")
ax1, ax2 = axes
primer_anio.plot(ax=ax1, column="viq", vmin=91, vmax=108, cmap=VEG_CMAP_0, legend=True)
ax1.axis("off")
im = ultimo_anio.plot(ax=ax2, column="viq", vmin=91, vmax=108, legend=True, cmap=VEG_CMAP_0)
ax2.axis("off")
plt.tight_layout()
